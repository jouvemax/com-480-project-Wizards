# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
global_electricity_sources = pd.read_csv("electricity-prod-source.csv")

# %%
# Just take the 2019 Values, not all countries have the 2020 values
# 71 countries have 2020 values, 235 (all countries) have 2019 values
global_electricity_sources_filtered= global_electricity_sources[global_electricity_sources['Year']==2019]

# %%
global_electricity_sources_filtered.head()
# Out:
#          Entity Code  Year  Electricity from coal (TWh)  \
# 225   Argentina  ARG  2020                     1.445719
# 336   Australia  AUS  2020                   135.099330
# 357     Austria  AUT  2020                     0.716660
# 393  Azerbaijan  AZE  2020                     0.000000
# 469  Bangladesh  BGD  2020                     4.423591
#
#      Electricity from gas (TWh)  Electricity from hydro (TWh)  \
# 225                   86.689660                     20.853642
# 336                   48.132519                     16.112890
# 357                   10.440827                     42.883119
# 393                   12.514432                      1.549350
# 469                   56.552108                      0.697582
#
#      Electricity from other renewables (TWh)  Electricity from solar (TWh)  \
# 225                                 1.893496                      1.344267
# 336                                 3.443160                     18.638820
# ...

# %%
total_coal = global_electricity_sources_filtered['Electricity from coal (TWh)'].sum()
total_gas = global_electricity_sources_filtered['Electricity from gas (TWh)'].sum()
total_renewables = global_electricity_sources_filtered['Electricity from other renewables (TWh)'].sum()
total_solar = global_electricity_sources_filtered['Electricity from solar (TWh)'].sum()
total_oil = global_electricity_sources_filtered['Electricity from oil (TWh)'].sum()
total_wind = global_electricity_sources_filtered['Electricity from wind (TWh)'].sum()
total_nuclear = global_electricity_sources_filtered['Electricity from nuclear (TWh)'].sum()

# %%
df = pd.DataFrame([[total_coal, total_gas, total_renewables, total_solar, total_oil, total_wind, total_nuclear]],columns=['Coal', 'Gas', 'Other renewables', 'Solar', 'Oil', 'Wind', 'Nuclear'])
df
# Out:
#            Coal           Gas  Other renewables        Solar          Oil  \
# 0  29248.341256  20246.388295       2401.997665  2411.554472  3468.780298
#
#           Wind      Nuclear
# 0  5072.475316  9827.427664

# %%
df.columns
# Out:
# Index(['Coal', 'Gas', 'Other renewables', 'Solar', 'Oil', 'Wind', 'Nuclear'], dtype='object')

# %%
fig = plt.figure(figsize=(8, 8), dpi = 150)
plt.pie(df.values, labels = df.columns)
plt.show()
#df.plot.pie(y=0, figsize=(5, 5))
